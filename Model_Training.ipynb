# %% [markdown]
# STEP-1

# %%
pip install torch torchvision torchaudio --index-url https://download.pytorch.org/whl/cu121

# %%
# !git clone https://github.com/ultralytics/yolov5
# Out:
# fatal: destination path 'yolov5' already exists and is not an empty directory.

# %%
# !cd yolov5 & pip install -r requirements.txt
# Out:
# ...
# WARNING: You are using pip version 20.2.3; however, version 24.3.1 is available.
# You should consider upgrading via the 'f:\mainproject\v\scripts\python.exe -m pip install --upgrade pip' command.

# %% [markdown]
# Imports

# %%
import torch
from matplotlib import pyplot as plt
import numpy as np
import cv2
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[10], line 2
#       1 import torch
# ----> 2 from matplotlib import pyplot as plt
#       3 import numpy as np
#       4 import cv2
#
# File f:\mainproject\v\lib\site-packages\matplotlib\pyplot.py:55
#      53 from cycler import cycler  # noqa: F401
#      54 import matplotlib
# ---> 55 import matplotlib.colorbar
#      56 import matplotlib.image
#      57 from matplotlib import _api
#
# File f:\mainproject\v\lib\site-packages\matplotlib\colorbar.py:19
#      16 import numpy as np
#      18 import matplotlib as mpl
# ---> 19 from matplotlib import _api, cbook, collections, cm, colors, contour, ticker
#      20 import matplotlib.artist as martist
#      21 import matplotlib.patches as mpatches
#
# File f:\mainproject\v\lib\site-packages\matplotlib\collections.py:20
#      17 import numpy as np
# ...

# %% [markdown]
# 2. Load Model

# %%
model = torch.hub.load('ultralytics/yolov5', 'yolov5s')
# Out:
# Using cache found in C:\Users\gurra/.cache\torch\hub\ultralytics_yolov5_master
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 model = torch.hub.load('ultralytics/yolov5', 'yolov5s')
#
# File f:\mainproject\v\lib\site-packages\torch\hub.py:647, in load(repo_or_dir, model, source, trust_repo, force_reload, verbose, skip_validation, *args, **kwargs)
#     637 if source == "github":
#     638     repo_or_dir = _get_cache_or_reload(
#     639         repo_or_dir,
#     640         force_reload,
#    (...)
#     644         skip_validation=skip_validation,
#     645     )
# --> 647 model = _load_local(repo_or_dir, model, *args, **kwargs)
#     648 return model
#
# File f:\mainproject\v\lib\site-packages\torch\hub.py:676, in _load_local(hubconf_dir, model, *args, **kwargs)
#     673     hub_module = _import_module(MODULE_HUBCONF, hubconf_path)
# ...

# %%
model
# Out:
# AutoShape(
#   (model): DetectMultiBackend(
#     (model): DetectionModel(
#       (model): Sequential(
#         (0): Conv(
#           (conv): Conv2d(3, 32, kernel_size=(6, 6), stride=(2, 2), padding=(2, 2))
#           (act): SiLU(inplace=True)
#         )
#         (1): Conv(
#           (conv): Conv2d(32, 64, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1))
#           (act): SiLU(inplace=True)
#         )
#         (2): C3(
#           (cv1): Conv(
#             (conv): Conv2d(64, 32, kernel_size=(1, 1), stride=(1, 1))
#             (act): SiLU(inplace=True)
#           )
#           (cv2): Conv(
#             (conv): Conv2d(64, 32, kernel_size=(1, 1), stride=(1, 1))
#             (act): SiLU(inplace=True)
#           )
#           (cv3): Conv(
#             (conv): Conv2d(64, 64, kernel_size=(1, 1), stride=(1, 1))
#             (act): SiLU(inplace=True)
#           )
#           (m): Sequential(
#             (0): Bottleneck(
#               (cv1): Conv(
# ...

# %% [markdown]
# 3. Make Detections with Images

# %%
img = 'https://upload.wikimedia.org/wikipedia/commons/thumb/e/e4/Cars_in_traffic_in_Auckland%2C_New_Zealand_-_copyright-free_photo_released_to_public_domain.jpg/800px-Cars_in_traffic_in_Auckland%2C_New_Zealand_-_copyright-free_photo_released_to_public_domain.jpg'

# %%
results = model(img)
results.print()
# Out:
# ---------------------------------------------------------------------------
# UnidentifiedImageError                    Traceback (most recent call last)
# Cell In[25], line 1
# ----> 1 results = model(img)
#       2 results.print()
#
# File g:\mainproject\venv\lib\site-packages\torch\nn\modules\module.py:1736, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1734     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1735 else:
# -> 1736     return self._call_impl(*args, **kwargs)
#
# File g:\mainproject\venv\lib\site-packages\torch\nn\modules\module.py:1747, in Module._call_impl(self, *args, **kwargs)
#    1742 # If we don't have any hooks, we want to skip the rest of the logic in
#    1743 # this function, and just call forward.
#    1744 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1745         or _global_backward_pre_hooks or _global_backward_hooks
# ...

# %%
# %matplotlib inline 
plt.imshow(np.squeeze(results.render()))
plt.show()

# %%
results.render()
# Out:
# [array([[[251, 216, 174],
#          [254, 220, 175],
#          [246, 213, 168],
#          ...,
#          [127, 149, 146],
#          [ 67,  79,  55],
#          [ 64,  70,  34]],
#
#         [[235, 201, 156],
#          [233, 200, 155],
#          [221, 189, 142],
#          ...,
#          [120, 142, 140],
#          [ 82,  92,  67],
#          [ 46,  52,  16]],
#
#         [[252, 220, 171],
#          [245, 213, 164],
#          [212, 180, 131],
#          ...,
#          [135, 155, 154],
#          [ 66,  74,  50],
#          [ 58,  62,  25]],
#
#         ...,
#
#         [[ 61,  69,  80],
#          [ 64,  72,  83],
#          [ 61,  69,  80],
#          ...,
#          [ 47,  52,  56],
#          [ 48,  53,  57],
#          [ 49,  54,  58]],
#
#         [[ 56,  64,  75],
#          [ 72,  80,  91],
#          [ 70,  78,  89],
#          ...,
#          [ 48,  53,  57],
#          [ 48,  53,  57],
#          [ 50,  55,  59]],
#
#         [[ 64,  72,  83],
# ...

# %% [markdown]
# 5. Train from scratch

# %%
import uuid   # Unique identifier
import os
import time

# %%
# !git clone https://github.com/tzutalin/labelImg
# Out:
# fatal: destination path 'labelImg' already exists and is not an empty directory.

# %%
# !pip install pyqt5 lxml --upgrade
# !cd labelImg && pyrcc5 -o libs/resources.py resources.qrc
# Out:
# Requirement already up-to-date: pyqt5 in f:\mainproject\v\lib\site-packages (5.15.11)
# Requirement already up-to-date: lxml in f:\mainproject\v\lib\site-packages (5.3.0)
# ...
# WARNING: You are using pip version 20.2.3; however, version 24.3.1 is available.
# You should consider upgrading via the 'f:\mainproject\v\scripts\python.exe -m pip install --upgrade pip' command.

# %%
# !cd yolov5 && python train.py --img 750 --batch 16 --epochs 15 --data dataset.yaml --weights yolov5s.pt --workers 2
# Out:
# WARNING âš ï¸� Python>=3.10 is required, but Python==3.9.0 is currently installed
# train: weights=yolov5s.pt, cfg=, data=dataset.yaml, hyp=data\hyps\hyp.scratch-low.yaml, epochs=15, batch_size=16, imgsz=750, rect=False, resume=False, nosave=False, noval=False, noautoanchor=False, noplots=False, evolve=None, evolve_population=data\hyps, resume_evolve=None, bucket=, cache=None, image_weights=False, device=, multi_scale=False, single_cls=False, optimizer=SGD, sync_bn=False, workers=2, project=runs\train, name=exp, exist_ok=False, quad=False, cos_lr=False, label_smoothing=0.0, patience=100, freeze=[0], save_period=-1, seed=0, local_rank=-1, entity=None, upload_dataset=False, bbox_interval=-1, artifact_alias=latest, ndjson_console=False, ndjson_file=False
# github: up to date with https://github.com/ultralytics/yolov5
# YOLOv5  v7.0-376-gbcd88eaf Python-3.9.0 torch-2.5.0+cu121 CUDA:0 (NVIDIA GeForce GTX 1650, 4096MiB)
#
# ...

# %% [markdown]
# 6. Load Custom Model

# %%
model = torch.hub.load('ultralytics/yolov5', 'custom', path='yolov5/runs/train/exp2/weights/last.pt', force_reload=True)
# Out:
# Downloading: "https://github.com/ultralytics/yolov5/zipball/master" to C:\Users\gurra/.cache\torch\hub\master.zip

# %%
img = os.path.join('data','test', 'images', '019bfb6ea7846181a_jpg.rf.8fabb32427521bb05200586abc9f3167.jpg')

# %%
results = model(img)
# Out:
# C:\Users\gurra/.cache\torch\hub\ultralytics_yolov5_master\models\common.py:892: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):

# %%
results.print()
# Out:
# image 1/1: 608x608 4 guns
# Speed: 966.4ms pre-process, 8221.3ms inference, 383.8ms NMS per image at shape (1, 3, 640, 640)

# %%
# %matplotlib inline 
plt.imshow(np.squeeze(results.render()))
plt.show()

# %%
cap = cv2.VideoCapture(0)
while cap.isOpened():
    ret, frame = cap.read()
    
    # Make detections 
    results = model(frame)
    
    cv2.imshow('YOLO', np.squeeze(results.render()))
    
    if cv2.waitKey(10) & 0xFF == ord('q'):
        break
cap.release()
cv2.destroyAllWindows()
# Out:
# C:\Users\gurra/.cache\torch\hub\ultralytics_yolov5_master\models\common.py:894: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# C:\Users\gurra/.cache\torch\hub\ultralytics_yolov5_master\models\common.py:894: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# C:\Users\gurra/.cache\torch\hub\ultralytics_yolov5_master\models\common.py:894: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# C:\Users\gurra/.cache\torch\hub\ultralytics_yolov5_master\models\common.py:894: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# ...

# %%
pip install torch torchvision torchaudio --index-url https://download.pytorch.org/whl/cu121 
# !git clone https://github.com/ultralytics/yolov5
# !cd yolov5 & pip install -r requirements.txt
import uuid   # Unique identifier
import os
import time
import torch
from matplotlib import pyplot as plt
import numpy as np
import cv2
# !git clone https://github.com/tzutalin/labelImg
# !pip install pyqt5 lxml --upgrade
# !cd labelImg && pyrcc5 -o libs/resources.py resources.qrc
# !cd yolov5 && python train.py --img 750 --batch 16 --epochs 15 --data dataset.yaml --weights yolov5s.pt --workers 2
model = torch.hub.load('ultralytics/yolov5', 'custom', path='yolov5/runs/train/exp2/weights/last.pt', force_reload=True)
cap = cv2.VideoCapture(0)
while cap.isOpened():
    ret, frame = cap.read()
    
    # Make detections 
    results = model(frame)
    
    cv2.imshow('YOLO', np.squeeze(results.render()))
    
    if cv2.waitKey(10) & 0xFF == ord('q'):
        break
cap.release()
cv2.destroyAllWindows()
# Out:
# Looking in indexes: https://download.pytorch.org/whl/cu121
# ...
# Note: you may need to restart the kernel to use updated packages.
# WARNING: You are using pip version 20.2.3; however, version 24.3.1 is available.
# You should consider upgrading via the 'f:\mainproject\v\Scripts\python.exe -m pip install --upgrade pip' command.
